# %% [markdown]
# Reading a CSV file

# %%
import pandas as pd
import numpy as np

# %%
customers_data = pd.read_csv("customers.csv")

# %%
customers_data
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
customers_data.head(10)
# Out:
#    Index      Customer Id First Name  Last Name                      Company  \
# 0      1  EB54EF1154C3A78    Heather   Callahan                 Mosley-David
# 1      2  10dAcafEBbA5FcA   Kristina    Ferrell     Horn, Shepard and Watson
# 2      3  67DAB15Ebe4BE4a     Briana   Andersen                  Irwin-Oneal
# 3      4  6d350C5E5eDB4EE      Patty      Ponce             Richardson Group
# 4      5  5820deAdCF23EFe   Kathleen  Mccormick                 Carson-Burch
# 5      6  E1CDEaC63fDd5aA     Trevor        Lee                 Maddox Group
# 6      7  3e1187fCcebC8d2     Mathew    Hoffman     Bender, Pittman and Kidd
# 7      8  47C5cEE243c9A7b      Glenn    Wiggins                 Glenn-Harvey
# 8      9  cacaD68a5e4BF4b      Bruce      Payne      Arroyo, Cain and Hudson
# 9     10  436b9c41cfb1fa3    Brendan     Franco  Schaefer, Blair and Shaffer
#
#                  City                      Country                Phone 1  \
# ...

# %%
customers_data.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
customers_data.index.to_numpy()
# Out:
# array([   0,    1,    2, ..., 9997, 9998, 9999], shape=(10000,))

# %%
customers_array=customers_data.to_numpy()

# %%
customers_data.loc[customers_data.index % 2 == 0]
# Out:
#       Index      Customer Id First Name  Last Name  \
# 0         1  EB54EF1154C3A78    Heather   Callahan
# 2         3  67DAB15Ebe4BE4a     Briana   Andersen
# 4         5  5820deAdCF23EFe   Kathleen  Mccormick
# 6         7  3e1187fCcebC8d2     Mathew    Hoffman
# 8         9  cacaD68a5e4BF4b      Bruce      Payne
# ...     ...              ...        ...        ...
# 9990   9991  4eb63eAE66E3CCC       Todd     Pierce
# 9992   9993  bdbA1F0053EDA7A   Jennifer     Haynes
# 9994   9995  D7E40cCBde64d59        Kim      Yoder
# 9996   9997  C1C62ff90D0AfED   Jeremiah       Pena
# 9998   9999  5dB06C3Fab5CCCb       Evan   Humphrey
#
#                             Company               City           Country  \
# 0                      Mosley-David   Lake Jeffborough            Norway
# 2                       Irwin-Oneal        East Jordan             Nepal
# 4                      Carson-Burch        Andresmouth             Macao
# ...

# %%
customers_data.loc[customers_data["Country"] == "Norway"]
# Out:
#       Index      Customer Id First Name  Last Name  \
# 0         1  EB54EF1154C3A78    Heather   Callahan
# 233     234  bA3c7355abEB0Aa   Danielle      Huang
# 293     294  78ac17Cc0E0b444      Danny       Hall
# 313     314  E44e636cfE26CfB      Maria     Conrad
# 383     384  8efE4D4084590A0     Kristi     Cortez
# 420     421  68fbb98f6EbD971       Jack    Robbins
# 480     481  d3fF4F1DceACA2D  Christian   Thornton
# 662     663  45fAcb9b399d894     Andres       Nash
# 1577   1578  23a1CeD8A626af7      Traci     Cooper
# 1862   1863  7d60D2dDF121acd      Cathy     Jarvis
# 1961   1962  3c4A0F6eC172711     Denise     Medina
# 2127   2128  0FE8eA68A3E2D0f    Patrick        Ray
# 2208   2209  F5f264c481eaE1d     Morgan     Robles
# 2260   2261  fA5FF5fbE098ea7      Randy      Rivas
# 2406   2407  eF265Ffe5F32251      Darin       Frye
# 2635   2636  A6acfb993EF51cd      Donna      Tyler
# 3220   3221  CC9B6713dc46eA7      Jerry     Howard
# ...

# %%
customers_data.iloc[:, 4]
# Out:
# 0                   Mosley-David
# 1       Horn, Shepard and Watson
# 2                    Irwin-Oneal
# 3               Richardson Group
# 4                   Carson-Burch
#                   ...
# 9995              Richardson LLC
# 9996                 Hodge-Nixon
# 9997                    Vang LLC
# 9998                   Gould Ltd
# 9999                Burns-Holden
# Name: Company, Length: 10000, dtype: object

# %%
customers_data.iloc[:, 4].head(5)
# Out:
# 0                Mosley-David
# 1    Horn, Shepard and Watson
# 2                 Irwin-Oneal
# 3            Richardson Group
# 4                Carson-Burch
# Name: Company, dtype: object

# %%
customers_data.iloc[0:98:3]
# Out:
#     Index      Customer Id First Name  Last Name  \
# 0       1  EB54EF1154C3A78    Heather   Callahan
# 3       4  6d350C5E5eDB4EE      Patty      Ponce
# 6       7  3e1187fCcebC8d2     Mathew    Hoffman
# 9      10  436b9c41cfb1fa3    Brendan     Franco
# 12     13  c388ECa44FFe37c       Dave      Moran
# 15     16  2cfDE68A372cC7A      Larry     Newton
# 18     19  dB52fA7Bec665C1    Kristin   Valencia
# 21     22  Beb0D2e4BA54a51        Roy      Brock
# 24     25  E31a9699DF2A0eF     Philip      Flynn
# 27     28  b9B3B5f1ba40FD3    Roberta     Walton
# 30     31  3D72031D22EB2aC     Daniel     Harper
# 33     34  F0EdAbc86aac953     Ashley     Davies
# 36     37  E75a5870e952cd6    Richard    Bennett
# 39     40  C2378a0b119b425       Marc     Medina
# 42     43  DFcebf7063e11ac     Daniel       Bush
# 45     46  fF8bc9C72D6c38b       Jill    Esparza
# 48     49  E95Ce6e2d241660   Jonathon  Gillespie
# 51     52  a0eb3D0bDcfB8Bd     Judith    Fischer
# ...

# %%
customers_data.loc[customers_data["City"] == "Sheriville"].index
# Out:
# Index([96, 1833], dtype='int64')

# %%
salary = pd.Series(np.random.uniform(1000, 10000, 10000), name="Salary")

# %%
salary
# Out:
# 0       5794.425876
# 1       1132.459010
# 2       8070.843002
# 3       6371.284132
# 4       4585.782304
#            ...
# 9995    6954.723254
# 9996    5183.493333
# 9997    1963.159513
# 9998    2334.337582
# 9999    9541.143964
# Length: 10000, dtype: float64

# %%
result=pd.concat([customers_data, salary], axis=1)

# %%
result
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...

# %%
result
# Out:
#       Index      Customer Id First Name   Last Name                   Company  \
# 0         1  EB54EF1154C3A78    Heather    Callahan              Mosley-David
# 1         2  10dAcafEBbA5FcA   Kristina     Ferrell  Horn, Shepard and Watson
# 2         3  67DAB15Ebe4BE4a     Briana    Andersen               Irwin-Oneal
# 3         4  6d350C5E5eDB4EE      Patty       Ponce          Richardson Group
# 4         5  5820deAdCF23EFe   Kathleen   Mccormick              Carson-Burch
# ...     ...              ...        ...         ...                       ...
# 9995   9996  DD0caa06ebf217c     Meghan       Cline            Richardson LLC
# 9996   9997  C1C62ff90D0AfED   Jeremiah        Pena               Hodge-Nixon
# 9997   9998  2EfAa6Fe435A7DA      Peggy         Key                  Vang LLC
# 9998   9999  5dB06C3Fab5CCCb       Evan    Humphrey                 Gould Ltd
# 9999  10000  9903e8fF4D8Ff0F    Melissa  Montgomery              Burns-Holden
#
# ...
